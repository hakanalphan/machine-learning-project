# %% [markdown]
# ### finans verilerini cekmek

# %%
pip install yfinance
# Out:
# ...
#
#   Obtaining dependency information for yfinance from https://files.pythonhosted.org/packages/14/03/3c854ca3e02eedf614abba4b2e177c469bf3af58207fa30d5098c5d652fe/yfinance-0.2.37-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for multitasking>=0.0.7 from https://files.pythonhosted.org/packages/3e/8a/bb3160e76e844db9e69a413f055818969c8acade64e1a9ac5ce9dfdcf6c1/multitasking-0.0.11-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/314.6 kB ? eta -:--:--
#      --- ----------------------------------- 30.7/314.6 kB 1.3 MB/s eta 0:00:01
#      ------------- ------------------------ 112.6/314.6 kB 1.3 MB/s eta 0:00:01
#      ----------------------------- -------- 245.8/314.6 kB 1.9 MB/s eta 0:00:01
#      -------------------------------------- 314.6/314.6 kB 1.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
# ...

# %%
import pandas as pd
import seaborn as sns

# %%
import yfinance as yf

# %%
google=yf.Ticker('GOOGL')
df=google.history(period='id',start='2023-1-1',end='2024-2-29')

# %%
df.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2023-01-03 00:00:00-05:00  89.589996  91.050003  88.519997  89.120003
# 2023-01-04 00:00:00-05:00  90.349998  90.650002  87.269997  88.080002
# 2023-01-05 00:00:00-05:00  87.470001  87.570000  85.900002  86.199997
# 2023-01-06 00:00:00-05:00  86.790001  87.690002  84.860001  87.339996
# 2023-01-09 00:00:00-05:00  88.360001  90.050003  87.860001  88.019997
#
#                              Volume  Dividends  Stock Splits
# Date
# 2023-01-03 00:00:00-05:00  28131200        0.0           0.0
# 2023-01-04 00:00:00-05:00  34854800        0.0           0.0
# 2023-01-05 00:00:00-05:00  27194400        0.0           0.0
# 2023-01-06 00:00:00-05:00  41381500        0.0           0.0
# 2023-01-09 00:00:00-05:00  29003900        0.0           0.0

# %%
df['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
google=yf.Ticker('ERCB.IS')
df=google.history(period='id',start='2023-1-1',end='2024-2-29')

# %%
df.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-01-02 00:00:00+03:00  176.000000  183.800003  171.800003  176.000000
# 2023-01-03 00:00:00+03:00  179.000000  184.800003  173.199997  173.199997
# 2023-01-04 00:00:00+03:00  173.199997  175.000000  160.199997  161.100006
# 2023-01-05 00:00:00+03:00  161.100006  168.600006  148.000000  160.600006
# 2023-01-06 00:00:00+03:00  151.699997  159.500000  148.399994  153.699997
#
#                             Volume  Dividends  Stock Splits
# Date
# 2023-01-02 00:00:00+03:00  1887481        0.0           0.0
# 2023-01-03 00:00:00+03:00  2241481        0.0           0.0
# 2023-01-04 00:00:00+03:00  1444808        0.0           0.0
# 2023-01-05 00:00:00+03:00  1912927        0.0           0.0
# 2023-01-06 00:00:00+03:00  2011336        0.0           0.0

# %%
df=yf.download(['TSLA','APPL'],start='2023-1-1',end='2024-2-29')
# Out:
# Failed to get ticker 'APPL' reason: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# [*********************100%%**********************]  2 of 2 completed
#
# 1 Failed download:
# ['APPL']: Exception('%ticker%: No timezone found, symbol may be delisted')

# %%
df.head()
# Out:
# Price      Adj Close             Close             High              Low  \
# Ticker          APPL        TSLA  APPL        TSLA APPL        TSLA APPL
# Date
# 2023-01-03       NaN  108.099998   NaN  108.099998  NaN  118.800003  NaN
# 2023-01-04       NaN  113.639999   NaN  113.639999  NaN  114.589996  NaN
# 2023-01-05       NaN  110.339996   NaN  110.339996  NaN  111.750000  NaN
# 2023-01-06       NaN  113.059998   NaN  113.059998  NaN  114.389999  NaN
# 2023-01-09       NaN  119.769997   NaN  119.769997  NaN  123.519997  NaN
#
# Price                  Open             Volume
# Ticker            TSLA APPL        TSLA   APPL       TSLA
# Date
# 2023-01-03  104.639999  NaN  118.470001    NaN  231402800
# 2023-01-04  107.519997  NaN  109.110001    NaN  180389000
# 2023-01-05  107.160004  NaN  110.510002    NaN  157986300
# 2023-01-06  101.809998  NaN  103.000000    NaN  220911100
# 2023-01-09  117.110001  NaN  118.959999    NaN  190284000
